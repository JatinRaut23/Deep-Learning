# %% [markdown]
# <a href="https://colab.research.google.com/github/JatinRaut23/Deep-Learning/blob/main/RNN_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
docs = ['go india',
        'india india',
        'hip hip hurray',
        'jeetega bhai jeetega india jeetega',
        'bharat mata ki jai',
        'kohli kohli',
        'sachin sachin',
        'dhoni dhoni',
        'modi ji ki jai',
        'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
# Cleans text (optional)
# Converts words → numbers (critical)
# Handles unknown words
# Pads sequences

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
Sequences = tokenizer.texts_to_sequences(docs)
Sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(Sequences, padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
from keras import Sequential
from keras.layers import Embedding
from tensorflow.keras import layers

model= Sequential()
model.add(Embedding(input_dim=18, output_dim=2,))
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# array([[[-0.01715869, -0.0170592 ],
#         [-0.00592033,  0.00805483],
#         [-0.00793747, -0.03487565],
#         [-0.00793747, -0.03487565],
#         [-0.00793747, -0.03487565]],
#
#        [[-0.00592033,  0.00805483],
#         [-0.00592033,  0.00805483],
#         [-0.00793747, -0.03487565],
#         [-0.00793747, -0.03487565],
#         [-0.00793747, -0.03487565]],
#
#        [[-0.02242998,  0.02220155],
#         [-0.02242998,  0.02220155],
#         [ 0.01937426,  0.01416913],
#         [-0.00793747, -0.03487565],
#         [-0.00793747, -0.03487565]],
#
#        [[ 0.02529815, -0.01320609],
#         [ 0.00272676, -0.02291578],
#         [ 0.02529815, -0.01320609],
#         [-0.00592033,  0.00805483],
#         [ 0.02529815, -0.01320609]],
#
#        [[-0.04909449, -0.02085807],
#         [-0.02044957, -0.02310487],
#         [ 0.01376343,  0.03307334],
#         [ 0.02432594, -0.0286889 ],
# ...
